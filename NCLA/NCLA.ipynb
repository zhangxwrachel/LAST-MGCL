# %%
# -*- coding: utf-8 -*-
import argparse
import numpy as np
import time
import random
import torch
import torch.nn.functional as F
import dgl
from gat import GAT

from utils import load_network_data, get_train_data, random_planetoid_splits
from loss import multihead_contrastive_loss
import warnings
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

warnings.filterwarnings("ignore")

parser = argparse.ArgumentParser(description='GAT')
parser.add_argument("--gpu", type=int, default=0,
                    help="which GPU to use. Set -1 to use CPU.")
parser.add_argument("--epochs", type=int, default=2000,
                    help="number of training epochs")
parser.add_argument("--dataset", type=str, default="citeseer",
                    help="which dataset for training")
parser.add_argument("--num-heads", type=int, default=4,
                    help="number of hidden attention heads")
parser.add_argument("--num-layers", type=int, default=1,
                    help="number of hidden layers")
parser.add_argument("--num-hidden", type=int, default=32,
                    help="number of hidden units")
parser.add_argument("--tau", type=float, default=1,
                    help="temperature-scales")
parser.add_argument("--seed", type=int, default=1,
                    help="random seed")
parser.add_argument("--in-drop", type=float, default=0.6,
                    help="input feature dropout")
parser.add_argument("--attn-drop", type=float, default=0.5,
                    help="attention dropout")
parser.add_argument("--lr", type=float, default=0.01,
                    help="learning rate")
parser.add_argument('--weight-decay', type=float, default=1e-4,
                    help="weight decay")
parser.add_argument('--negative-slope', type=float, default=0.2,
                    help="the negative slope of leaky relu")

args = parser.parse_known_args()[0]
print(args)

random.seed(args.seed)
np.random.seed(args.seed)
torch.manual_seed(args.seed)

adj2, features, Y = load_network_data(args.dataset)
features[features > 0] = 1
g = dgl.from_scipy(adj2)

if args.gpu >= 0 and torch.cuda.is_available():
    cuda = True
    g = g.int().to(args.gpu)
else:
    cuda = False

features = torch.FloatTensor(features.todense())
f = open('NCLA_' + args.dataset + '.txt', 'a+')
f.write('\n\n\n{}\n'.format(args))
f.flush()

labels = np.argmax(Y, 1)
adj = torch.tensor(adj2.todense())

all_time = time.time()
num_feats = features.shape[1]
n_classes = Y.shape[1]
n_edges = g.number_of_edges()

# add self loop
g = dgl.remove_self_loop(g)
g = dgl.add_self_loop(g)

# create model
heads = ([args.num_heads] * args.num_layers)
model = GAT(g,
            args.num_layers,
            num_feats,
            args.num_hidden,
            heads,
            F.elu,
            args.in_drop,
            args.attn_drop,
            args.negative_slope)

if cuda:
    model.cuda()
    features = features.cuda()
    adj = adj.cuda()

# use optimizer
optimizer = torch.optim.Adam(
    model.parameters(), lr=args.lr, weight_decay=args.weight_decay)

# initialize graph
dur = []
test_acc = 0

counter = 0
min_train_loss = 100
early_stop_counter = 100
best_t = -1

for epoch in range(args.epochs): #按照 args.epochs 指定的次数进行多轮训练。
    if epoch >= 0:
        t0 = time.time()   #计时
    model.train() #模型设置为训练模式
    optimizer.zero_grad() #梯度清零
    heads = model(features)#然后进行前向传播以获得模型预测
    loss = multihead_contrastive_loss(heads, adj, tau=args.tau)
    loss.backward()
    optimizer.step()

    model.eval()
    with torch.no_grad():
        heads = model(features)
        loss_train = multihead_contrastive_loss(heads, adj, tau=args.tau)

    #如果训练损失连续 100 轮都没有下降，则进行提前停止
    if loss_train < min_train_loss:
        counter = 0
        min_train_loss = loss_train
        best_t = epoch
        torch.save(model.state_dict(), 'best_NCLA.pkl')
    else:
        counter += 1

    if counter >= early_stop_counter:
        print('early stop')
        break

    if epoch >= 0:
        dur.append(time.time() - t0)

    print("Epoch {:04d} | Time(s) {:.4f} | TrainLoss {:.4f} ".
          format(epoch + 1, np.mean(dur), loss_train.item()))

print('Loading {}th epoch'.format(best_t))
model.load_state_dict(torch.load('best_NCLA.pkl'))#训练结束后，从最佳轮次加载模型参数 
model.eval()#将模型设置为评估模式，并通过模型传递特征以获得嵌入
with torch.no_grad():
    heads = model(features)
embeds = torch.cat(heads, axis=1)  #从所有头部中串联嵌入
embeds = embeds.detach().cpu()

Accuaracy_test_allK = []
numRandom = 20

for train_num in [1, 2, 3, 4, 20]:

    AccuaracyAll = []
    for random_state in range(numRandom):
        print(
            "\n=============================%d-th random split with training num %d============================="
            % (random_state + 1, train_num))

        if train_num == 20:
            if args.dataset in ['cora', 'citeseer', 'pubmed']:
                # train_num per class: 20, val_num: 500, test: 1000
                val_num = 500
                idx_train, idx_val, idx_test = random_planetoid_splits(n_classes, torch.tensor(labels), train_num,
                                                                       random_state)
            else:
                # Coauthor CS, Amazon Computers, Amazon Photo
                # train_num per class: 20, val_num per class: 30, test: rest
                val_num = 30
                idx_train, idx_val, idx_test = get_train_data(Y, train_num, val_num, random_state)

        else:
            val_num = 0  # do not use a validation set when the training labels are extremely limited
            idx_train, idx_val, idx_test = get_train_data(Y, train_num, val_num, random_state)

        train_embs = embeds[idx_train, :]
        val_embs = embeds[idx_val, :]
        test_embs = embeds[idx_test, :]

        if train_num == 20:
            # find the best parameter C using validation set
            best_val_score = 0.0
            for param in [1e-4, 1e-3, 1e-2, 0.1, 1, 10, 100]:
                LR = LogisticRegression(solver='liblinear', multi_class='ovr', random_state=0, C=param)
                LR.fit(train_embs, labels[idx_train])
                val_score = LR.score(val_embs, labels[idx_val])
                if val_score > best_val_score:
                    best_val_score = val_score
                    best_parameters = {'C': param}

            LR_best = LogisticRegression(solver='liblinear', multi_class='ovr', random_state=0, **best_parameters)

            LR_best.fit(train_embs, labels[idx_train])
            y_pred_test = LR_best.predict(test_embs)  # pred label
            print("Best accuracy on validation set:{:.4f}".format(best_val_score))
            print("Best parameters:{}".format(best_parameters))

        else:  # not use a validation set when the training labels are extremely limited
            LR = LogisticRegression(solver='liblinear', multi_class='ovr', random_state=0)
            LR.fit(train_embs, labels[idx_train])
            y_pred_test = LR.predict(test_embs)  # pred label

        test_acc = accuracy_score(labels[idx_test], y_pred_test)
        print("test accuaray:{:.4f}".format(test_acc))
        AccuaracyAll.append(test_acc)

    average_acc = np.mean(AccuaracyAll) * 100
    std_acc = np.std(AccuaracyAll) * 100
    print('avg accuracy over %d random splits: %.1f +/- %.1f, for train_num: %d, val_num:%d\n' % (
        numRandom, average_acc, std_acc, train_num, val_num))
    f.write('avg accuracy over %d random splits: %.1f +/- %.1f, for train_num: %d, val_num:%d\n' % (
        numRandom, average_acc, std_acc, train_num, val_num))
    f.flush()

    Accuaracy_test_allK.append(average_acc)

f.close()
# Out:
# Namespace(gpu=0, epochs=2000, dataset='citeseer', num_heads=4, num_layers=1, num_hidden=32, tau=1, seed=1, in_drop=0.6, attn_drop=0.5, lr=0.01, weight_decay=0.0001, negative_slope=0.2)
# GATConv层输入： 3703 32 4 0.6 0.5 0.2 False <function elu at 0x000001ED01E9EE80>
# num_layers: 1
# Epoch 0001 | Time(s) 1.2664 | TrainLoss 8.3548
# Epoch 0002 | Time(s) 1.1998 | TrainLoss 8.1778
# Epoch 0003 | Time(s) 1.1944 | TrainLoss 8.1104
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Desktop\毕业论文\代码\M-VIEW代码\NCLA-main\NCLA.ipynb 单元格 1 line 1
#     <a href='vscode-notebook-cell:/d%3A/Desktop/%E6%AF%95%E4%B8%9A%E8%AE%BA%E6%96%87/%E4%BB%A3%E7%A0%81/M-VIEW%E4%BB%A3%E7%A0%81/NCLA-main/NCLA.ipynb#W0sZmlsZQ%3D%3D?line=114'>115</a> optimizer.zero_grad() #梯度清零
#     <a href='vscode-notebook-cell:/d%3A/Desktop/%E6%AF%95%E4%B8%9A%E8%AE%BA%E6%96%87/%E4%BB%A3%E7%A0%81/M-VIEW%E4%BB%A3%E7%A0%81/NCLA-main/NCLA.ipynb#W0sZmlsZQ%3D%3D?line=115'>116</a> heads = model(features)#然后进行前向传播以获得模型预测
# --> <a href='vscode-notebook-cell:/d%3A/Desktop/%E6%AF%95%E4%B8%9A%E8%AE%BA%E6%96%87/%E4%BB%A3%E7%A0%81/M-VIEW%E4%BB%A3%E7%A0%81/NCLA-main/NCLA.ipynb#W0sZmlsZQ%3D%3D?line=116'>117</a> loss = multihead_contrastive_loss(heads, adj, tau=args.tau)
#     <a href='vscode-notebook-cell:/d%3A/Desktop/%E6%AF%95%E4%B8%9A%E8%AE%BA%E6%96%87/%E4%BB%A3%E7%A0%81/M-VIEW%E4%BB%A3%E7%A0%81/NCLA-main/NCLA.ipynb#W0sZmlsZQ%3D%3D?line=117'>118</a> loss.backward()
#     <a href='vscode-notebook-cell:/d%3A/Desktop/%E6%AF%95%E4%B8%9A%E8%AE%BA%E6%96%87/%E4%BB%A3%E7%A0%81/M-VIEW%E4%BB%A3%E7%A0%81/NCLA-main/NCLA.ipynb#W0sZmlsZQ%3D%3D?line=118'>119</a> optimizer.step()
#
# File d:\Desktop\毕业论文\代码\M-VIEW代码\NCLA-main\loss.py:19, in multihead_contrastive_loss(heads, adj, tau)
#      17 loss = torch.tensor(0, dtype=float, requires_grad=True)
#      18 for i in range(1, len(heads)):
# ---> 19     loss = loss + contrastive_loss(heads[0], heads[i], adj, tau=tau)
#      20 return loss / (len(heads) - 1)
#
# File d:\Desktop\毕业论文\代码\M-VIEW代码\NCLA-main\loss.py:9, in contrastive_loss(z1, z2, adj, mean, tau, hidden_norm)
#       6 def contrastive_loss(z1: torch.Tensor, z2: torch.Tensor, adj,
#       7                      mean: bool = True, tau: float = 1.0, hidden_norm: bool = True):
#       8     l1 = nei_con_loss(z1, z2, tau, adj, hidden_norm)
# ----> 9     l2 = nei_con_loss(z2, z1, tau, adj, hidden_norm)
#      10     ret = (l1 + l2) * 0.5
#      11     ret = ret.mean() if mean else ret.sum()
#
# File d:\Desktop\毕业论文\代码\M-VIEW代码\NCLA-main\loss.py:38, in nei_con_loss(z1, z2, tau, adj, hidden_norm)
#      35 nei_count = torch.squeeze(torch.tensor(nei_count))
#      37 f = lambda x: torch.exp(x / tau)
# ---> 38 intra_view_sim = f(sim(z1, z1, hidden_norm))
#      39 inter_view_sim = f(sim(z1, z2, hidden_norm))
#      41 loss = (inter_view_sim.diag() + (intra_view_sim.mul(adj)).sum(1) + (inter_view_sim.mul(adj)).sum(1)) / (
#      42         intra_view_sim.sum(1) + inter_view_sim.sum(1) - intra_view_sim.diag())
#
# File d:\Desktop\毕业论文\代码\M-VIEW代码\NCLA-main\loss.py:27, in sim(z1, z2, hidden_norm)
#      25     z1 = F.normalize(z1)
#      26     z2 = F.normalize(z2)
# ---> 27 return torch.mm(z1, z2.t())
#
# KeyboardInterrupt:

# %%
# -*- coding: utf-8 -*-
import argparse
import numpy as np
import time
import random
import torch
import torch.nn.functional as F
import dgl
from gat import GAT

from utils import load_network_data, get_train_data, random_planetoid_splits
from loss import multihead_contrastive_loss
import warnings
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

warnings.filterwarnings("ignore")

parser = argparse.ArgumentParser(description='GAT')
parser.add_argument("--gpu", type=int, default=0,
                    help="which GPU to use. Set -1 to use CPU.")
parser.add_argument("--epochs", type=int, default=2000,
                    help="number of training epochs")
parser.add_argument("--dataset", type=str, default="citeseer",
                    help="which dataset for training")
parser.add_argument("--num-heads", type=int, default=4,
                    help="number of hidden attention heads")
parser.add_argument("--num-layers", type=int, default=1,
                    help="number of hidden layers")
parser.add_argument("--num-hidden", type=int, default=32,
                    help="number of hidden units")
parser.add_argument("--tau", type=float, default=1,
                    help="temperature-scales")
parser.add_argument("--seed", type=int, default=1,
                    help="random seed")
parser.add_argument("--in-drop", type=float, default=0.6,
                    help="input feature dropout")
parser.add_argument("--attn-drop", type=float, default=0.5,
                    help="attention dropout")
parser.add_argument("--lr", type=float, default=0.01,
                    help="learning rate")
parser.add_argument('--weight-decay', type=float, default=1e-4,
                    help="weight decay")
parser.add_argument('--negative-slope', type=float, default=0.2,
                    help="the negative slope of leaky relu")

args = parser.parse_known_args()[0]
print(args)

random.seed(args.seed)
np.random.seed(args.seed)
torch.manual_seed(args.seed)

adj2, features, Y = load_network_data(args.dataset)
features[features > 0] = 1
g = dgl.from_scipy(adj2)

if args.gpu >= 0 and torch.cuda.is_available():
    cuda = True
    g = g.int().to(args.gpu)
else:
    cuda = False

features = torch.FloatTensor(features.todense())
f = open('NCLA_' + args.dataset + '.txt', 'a+')
f.write('\n\n\n{}\n'.format(args))
f.flush()

labels = np.argmax(Y, 1)
adj = torch.tensor(adj2.todense())

all_time = time.time()
num_feats = features.shape[1]
n_classes = Y.shape[1]
n_edges = g.number_of_edges()

# add self loop
g = dgl.remove_self_loop(g)
g = dgl.add_self_loop(g)

# create model
heads = ([args.num_heads] * args.num_layers)
model = GAT(g,
            args.num_layers,
            num_feats,
            args.num_hidden,
            heads,
            F.elu,
            args.in_drop,
            args.attn_drop,
            args.negative_slope)

if cuda:
    model.cuda()
    features = features.cuda()
    adj = adj.cuda()

# use optimizer
optimizer = torch.optim.Adam(
    model.parameters(), lr=args.lr, weight_decay=args.weight_decay)

# initialize graph
dur = []
test_acc = 0

counter = 0
min_train_loss = 100
early_stop_counter = 100
best_t = -1

for epoch in range(1): #按照 args.epochs 指定的次数进行多轮训练。
    if epoch >= 0:
        t0 = time.time()   #计时
    model.train() #模型设置为训练模式
    optimizer.zero_grad() #梯度清零
    heads= model(features)#然后进行前向传播以获得模型预测
    loss = multihead_contrastive_loss(heads, adj, tau=args.tau)
    loss.backward()
    optimizer.step()

    model.eval()
    with torch.no_grad():
        heads = model(features)
        loss_train = multihead_contrastive_loss(heads, adj, tau=args.tau)

    #如果训练损失连续 100 轮都没有下降，则进行提前停止
    if loss_train < min_train_loss:
        counter = 0
        min_train_loss = loss_train
        best_t = epoch
        torch.save(model.state_dict(), 'best_NCLA.pkl')
    else:
        counter += 1

    if counter >= early_stop_counter:
        print('early stop')
        break

    if epoch >= 0:
        dur.append(time.time() - t0)

    print("Epoch {:04d} | Time(s) {:.4f} | TrainLoss {:.4f} ".
          format(epoch + 1, np.mean(dur), loss_train.item()))

print('Loading {}th epoch'.format(best_t))
model.load_state_dict(torch.load('best_NCLA.pkl'))#训练结束后，从最佳轮次加载模型参数 
model.eval()#将模型设置为评估模式，并通过模型传递特征以获得嵌入
with torch.no_grad():
    heads = model(features)
# Out:
# Namespace(gpu=0, epochs=2000, dataset='citeseer', num_heads=4, num_layers=1, num_hidden=32, tau=1, seed=1, in_drop=0.6, attn_drop=0.5, lr=0.01, weight_decay=0.0001, negative_slope=0.2)
# GATConv层输入： 3703 32 4 0.6 0.5 0.2 False <function elu at 0x0000020C82A76980>
# Epoch 0001 | Time(s) 1.2394 | TrainLoss 8.3548
# Loading 0th epoch

# %%
print('GATConv层输入：',in_dim, num_hidden, heads[0],
            feat_drop, attn_drop, negative_slope, False, self.activation)

# %%
augmented_graph_features
# Out:
# [tensor([[[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.4445, -0.0132,  0.2077,  ..., -0.2958, -0.2379, -0.0523],
#           [-0.1771, -0.5300,  0.2608,  ..., -0.3066, -0.5625,  0.2906],
#           [ 0.4795, -0.3555, -0.0991,  ..., -0.2951, -0.0933, -0.5426]],
#
#          [[ 0.3860, -0.1873,  0.2311,  ...,  0.3187, -0.2169, -0.3955],
#           [-0.0424, -0.0533, -0.1645,  ...,  0.0020, -0.1539, -0.1314],
#           [-0.1668, -0.0537, -0.0587,  ..., -0.0556, -0.1276,  0.0428],
#           [ 0.0868, -0.0298, -0.0330,  ...,  0.0730, -0.1953, -0.0856]],
#
#          [[-0.2173, -0.1561,  0.1978,  ...,  0.0582, -0.1489,  0.1396],
#           [ 0.1280, -0.3042, -0.5491,  ...,  0.2454, -0.0274, -0.1619],
#           [-0.2521,  0.0945, -0.1521,  ..., -0.0140, -0.0798,  0.0476],
#           [ 0.0059, -0.1211, -0.3256,  ..., -0.0262, -0.1508, -0.1379]],
#
#          ...,
#
#          [[-0.0097,  0.1236, -0.0399,  ..., -0.1214,  0.1626, -0.0693],
#           [ 0.0592,  0.0488, -0.2379,  ...,  0.0690,  0.0174, -0.2193],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0207,  0.3500,  0.0438,  ...,  0.0776,  0.2349,  0.4670]],
#
#          [[-0.2618, -0.1843,  0.0120,  ...,  0.2215,  0.0985, -0.1779],
#           [-0.0333,  0.0214, -0.1201,  ..., -0.3588, -0.0245, -0.0013],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.2550,  0.0923,  0.1767,  ...,  0.3219,  0.2851, -0.0752]],
#
#          [[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.1521,  0.4014,  0.1154,  ..., -0.3352, -0.3019,  0.1271],
#           [ 0.0915,  0.1232,  0.1483,  ..., -0.2457, -0.2612, -0.2496],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]],
#         grad_fn=<EluBackward0>)]

# %%
augmented_graph_features.shape()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Desktop\毕业论文\NCLA-main\NCLA-main\Untitled-1.ipynb 单元格 5 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Desktop/%E6%AF%95%E4%B8%9A%E8%AE%BA%E6%96%87/NCLA-main/NCLA-main/Untitled-1.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> augmented_graph_features.shape()
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
type(augmented_graph_features)
# Out:
# list

# %%
my_tensor = torch.tensor(augmented_graph_features)

# 查看张量的长度
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Desktop\毕业论文\NCLA-main\NCLA-main\Untitled-1.ipynb 单元格 7 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Desktop/%E6%AF%95%E4%B8%9A%E8%AE%BA%E6%96%87/NCLA-main/NCLA-main/Untitled-1.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> my_tensor = torch.tensor(augmented_graph_features)
#       <a href='vscode-notebook-cell:/d%3A/Desktop/%E6%AF%95%E4%B8%9A%E8%AE%BA%E6%96%87/NCLA-main/NCLA-main/Untitled-1.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> # 查看张量的长度
#
# ValueError: only one element tensors can be converted to Python scalars

# %%
import torch

# 假设 augmented_graph_features 是一个列表，其中包含多个张量

# 使用 torch.stack() 将列表中的张量堆叠成一个新的张量
my_tensor = torch.stack(augmented_graph_features)

# 查看张量的尺寸
print("Tensor Size:", my_tensor.size())
# Out:
# Tensor Size: torch.Size([1, 3327, 4, 32])

# %%
my_tensor
# Out:
# tensor([[[[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.4445, -0.0132,  0.2077,  ..., -0.2958, -0.2379, -0.0523],
#           [-0.1771, -0.5300,  0.2608,  ..., -0.3066, -0.5625,  0.2906],
#           [ 0.4795, -0.3555, -0.0991,  ..., -0.2951, -0.0933, -0.5426]],
#
#          [[ 0.3860, -0.1873,  0.2311,  ...,  0.3187, -0.2169, -0.3955],
#           [-0.0424, -0.0533, -0.1645,  ...,  0.0020, -0.1539, -0.1314],
#           [-0.1668, -0.0537, -0.0587,  ..., -0.0556, -0.1276,  0.0428],
#           [ 0.0868, -0.0298, -0.0330,  ...,  0.0730, -0.1953, -0.0856]],
#
#          [[-0.2173, -0.1561,  0.1978,  ...,  0.0582, -0.1489,  0.1396],
#           [ 0.1280, -0.3042, -0.5491,  ...,  0.2454, -0.0274, -0.1619],
#           [-0.2521,  0.0945, -0.1521,  ..., -0.0140, -0.0798,  0.0476],
#           [ 0.0059, -0.1211, -0.3256,  ..., -0.0262, -0.1508, -0.1379]],
#
#          ...,
#
#          [[-0.0097,  0.1236, -0.0399,  ..., -0.1214,  0.1626, -0.0693],
#           [ 0.0592,  0.0488, -0.2379,  ...,  0.0690,  0.0174, -0.2193],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0207,  0.3500,  0.0438,  ...,  0.0776,  0.2349,  0.4670]],
#
#          [[-0.2618, -0.1843,  0.0120,  ...,  0.2215,  0.0985, -0.1779],
#           [-0.0333,  0.0214, -0.1201,  ..., -0.3588, -0.0245, -0.0013],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.2550,  0.0923,  0.1767,  ...,  0.3219,  0.2851, -0.0752]],
#
#          [[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [-0.1521,  0.4014,  0.1154,  ..., -0.3352, -0.3019,  0.1271],
#           [ 0.0915,  0.1232,  0.1483,  ..., -0.2457, -0.2612, -0.2496],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]]],
#        grad_fn=<StackBackward0>)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.datasets import Planetoid
from torchmeta.datasets import Cora
from torchmeta.transforms import ClassSplitter, Categorical
from torchmeta.utils.data import BatchMetaDataLoader
from torchmeta.modules import MetaModule
from torchmeta.modules.utils import get_subdict

# Define a simple graph neural network model
class GraphNet(MetaModule):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(GraphNet, self).__init__()
        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, hidden_dim)
        self.conv3 = GCNConv(hidden_dim, output_dim)

    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        x = F.relu(self.conv2(x, edge_index))
        x = self.conv3(x, edge_index)
        return F.log_softmax(x, dim=1)

# Define a model that wraps the GraphNet for MAML
class MetaGraphNet(MetaModule):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(MetaGraphNet, self).__init__()
        self.graphnet = GraphNet(input_dim, hidden_dim, output_dim)

    def forward(self, x, edge_index):
        return self.graphnet(x, edge_index)

# Define MAML algorithm
class MAML:
    def __init__(self, model, lr_inner=0.01, lr_outer=0.001):
        self.model = model
        self.lr_inner = lr_inner
        self.lr_outer = lr_outer
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=lr_outer)

    def inner_update(self, task):
        support_x, support_y = task['train']
        query_x, query_y = task['test']

        # Clone the model to initialize inner loop parameters
        inner_model = get_subdict(self.model, ['graphnet']).train()
        
        # Perform inner loop updates on support set
        for _ in range(num_inner_updates):
            logits = inner_model(support_x, task['edge_index'])
            loss = F.nll_loss(logits, support_y)
            self.model.zero_grad()
            grads = torch.autograd.grad(loss, inner_model.parameters())
            inner_model.update_params(lr=self.lr_inner, source_params=grads)

        # Compute loss on query set
        query_logits = inner_model(query_x, task['edge_index'])
        loss = F.nll_loss(query_logits, query_y)
        return loss

    def outer_update(self, tasks):
        meta_loss = torch.stack([self.inner_update(task) for task in tasks]).mean()
        self.optimizer.zero_grad()
        meta_loss.backward()
        self.optimizer.step()

# Load Cora dataset
dataset = Cora('data', num_classes_per_task=5, meta_train=True, meta_val=True, meta_test=False)
dataset = ClassSplitter(shuffle=True, num_train_per_class=1, num_test_per_class=10)(dataset)
meta_dataset = BatchMetaDataLoader(dataset, batch_size=16)

# Initialize model for MAML
model = MetaGraphNet(input_dim=dataset.num_features, hidden_dim=64, output_dim=dataset.num_classes)
maml = MAML(model)

# Train meta-learning model
num_epochs = 100
num_inner_updates = 5
for epoch in range(num_epochs):
    for tasks in meta_dataset:
        maml.outer_update(tasks)

# Get enhanced adjacency matrix and node features
enhanced_adj = []
enhanced_features = []
for task in meta_dataset:
    support_data, _ = task['train']
    enhanced_adj.append(support_data.edge_index)
    enhanced_features.append(support_data.x)
enhanced_adj = torch.stack(enhanced_adj)
enhanced_features = torch.stack(enhanced_features)

print("Enhanced adjacency matrix shape:", enhanced_adj.shape)
print("Enhanced node features shape:", enhanced_features.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\Desktop\毕业论文\NCLA-main\NCLA-main\Untitled-1.ipynb 单元格 12 line 6
#       <a href='vscode-notebook-cell:/d%3A/Desktop/%E6%AF%95%E4%B8%9A%E8%AE%BA%E6%96%87/NCLA-main/NCLA-main/Untitled-1.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> from torch_geometric.nn import GCNConv
#       <a href='vscode-notebook-cell:/d%3A/Desktop/%E6%AF%95%E4%B8%9A%E8%AE%BA%E6%96%87/NCLA-main/NCLA-main/Untitled-1.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a> from torch_geometric.datasets import Planetoid
# ----> <a href='vscode-notebook-cell:/d%3A/Desktop/%E6%AF%95%E4%B8%9A%E8%AE%BA%E6%96%87/NCLA-main/NCLA-main/Untitled-1.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a> from torchmeta.datasets import Cora
#       <a href='vscode-notebook-cell:/d%3A/Desktop/%E6%AF%95%E4%B8%9A%E8%AE%BA%E6%96%87/NCLA-main/NCLA-main/Untitled-1.ipynb#X14sZmlsZQ%3D%3D?line=6'>7</a> from torchmeta.transforms import ClassSplitter, Categorical
#       <a href='vscode-notebook-cell:/d%3A/Desktop/%E6%AF%95%E4%B8%9A%E8%AE%BA%E6%96%87/NCLA-main/NCLA-main/Untitled-1.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a> from torchmeta.utils.data import BatchMetaDataLoader
#
# ModuleNotFoundError: No module named 'torchmeta'

# %%
# -*- coding: utf-8 -*-
import argparse
import numpy as np
import time
import random
import torch
import torch.nn.functional as F
import dgl
from gat import GAT
from utils import load_network_data, get_train_data, random_planetoid_splits
from loss import multihead_contrastive_loss
import warnings
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

warnings.filterwarnings("ignore")

parser = argparse.ArgumentParser(description='GAT')
parser.add_argument("--gpu", type=int, default=0,
                    help="which GPU to use. Set -1 to use CPU.")
parser.add_argument("--epochs", type=int, default=2000,
                    help="number of training epochs")
parser.add_argument("--dataset", type=str, default="cora",
                    help="which dataset for training")
parser.add_argument("--num-heads", type=int, default=4,
                    help="number of hidden attention heads")
parser.add_argument("--num-layers", type=int, default=1,
                    help="number of hidden layers")
parser.add_argument("--num-hidden", type=int, default=32,
                    help="number of hidden units")
parser.add_argument("--tau", type=float, default=1,
                    help="temperature-scales")
parser.add_argument("--seed", type=int, default=1,
                    help="random seed")
parser.add_argument("--in-drop", type=float, default=0.6,
                    help="input feature dropout")
parser.add_argument("--attn-drop", type=float, default=0.5,
                    help="attention dropout")
parser.add_argument("--lr", type=float, default=0.01,
                    help="learning rate")
parser.add_argument('--weight-decay', type=float, default=1e-4,
                    help="weight decay")
parser.add_argument('--negative-slope', type=float, default=0.2,
                    help="the negative slope of leaky relu")
args = parser.parse_known_args()[0]
print(args)

random.seed(args.seed)
np.random.seed(args.seed)
torch.manual_seed(args.seed)

adj2, features, Y = load_network_data(args.dataset)
features[features > 0] = 1
g = dgl.from_scipy(adj2)

if args.gpu >= 0 and torch.cuda.is_available():
    cuda = True
    g = g.int().to(args.gpu)
else:
    cuda = False

features = torch.FloatTensor(features.todense())
f = open('NCLA_' + args.dataset + '.txt', 'a+')
f.write('\n\n\n{}\n'.format(args))
f.flush()

labels = np.argmax(Y, 1)
adj = torch.tensor(adj2.todense())

all_time = time.time()
num_feats = features.shape[1]
n_classes = Y.shape[1]
n_edges = g.number_of_edges()

# add self loop
g = dgl.remove_self_loop(g)
g = dgl.add_self_loop(g)

# create model
heads = ([args.num_heads] * args.num_layers)
model = GAT(g,
            args.num_layers,
            num_feats,
            args.num_hidden,
            heads,
            F.elu,
            args.in_drop,
            args.attn_drop,
            args.negative_slope)

if cuda:
    model.cuda()
    features = features.cuda()
    adj = adj.cuda()

# use optimizer
optimizer = torch.optim.Adam(
    model.parameters(), lr=args.lr, weight_decay=args.weight_decay)

# initialize graph
dur = []
test_acc = 0

counter = 0
min_train_loss = 100
early_stop_counter = 100
best_t = -1

for epoch in range(args.epochs):
    if epoch >= 0:
        t0 = time.time()
    model.train()
    optimizer.zero_grad()
    heads = model(features)
    loss = multihead_contrastive_loss(heads, adj, tau=args.tau)
    loss.backward()
    optimizer.step()

    model.eval()
    with torch.no_grad():
        heads = model(features)
        loss_train = multihead_contrastive_loss(heads, adj, tau=args.tau)

    # early stop if loss does not decrease for 100 consecutive epochs
    if loss_train < min_train_loss:
        counter = 0
        min_train_loss = loss_train
        best_t = epoch
        torch.save(model.state_dict(), 'best_NCLA.pkl')
    else:
        counter += 1

    if counter >= early_stop_counter:
        print('early stop')
        break

    if epoch >= 0:
        dur.append(time.time() - t0)

    print("Epoch {:04d} | Time(s) {:.4f} | TrainLoss {:.4f} ".
          format(epoch + 1, np.mean(dur), loss_train.item()))

print('Loading {}th epoch'.format(best_t))
model.load_state_dict(torch.load('best_NCLA.pkl'))
model.eval()
with torch.no_grad():
    heads = model(features)
embeds = torch.cat(heads, axis=1)  # concatenate emb learned by all heads
embeds = embeds.detach().cpu()

Accuaracy_test_allK = []
numRandom = 20

for train_num in [1, 2, 3, 4, 20]:

    AccuaracyAll = []
    for random_state in range(numRandom):
        print(
            "\n=============================%d-th random split with training num %d============================="
            % (random_state + 1, train_num))

        if train_num == 20:
            if args.dataset in ['cora', 'citeseer', 'pubmed']:
                # train_num per class: 20, val_num: 500, test: 1000
                val_num = 500
                idx_train, idx_val, idx_test = random_planetoid_splits(n_classes, torch.tensor(labels), train_num,
                                                                       random_state)
            else:
                # Coauthor CS, Amazon Computers, Amazon Photo
                # train_num per class: 20, val_num per class: 30, test: rest
                val_num = 30
                idx_train, idx_val, idx_test = get_train_data(Y, train_num, val_num, random_state)

        else:
            val_num = 0  # do not use a validation set when the training labels are extremely limited
            idx_train, idx_val, idx_test = get_train_data(Y, train_num, val_num, random_state)

        train_embs = embeds[idx_train, :]
        val_embs = embeds[idx_val, :]
        test_embs = embeds[idx_test, :]

        if train_num == 20:
            # find the best parameter C using validation set
            best_val_score = 0.0
            for param in [1e-4, 1e-3, 1e-2, 0.1, 1, 10, 100]:
                LR = LogisticRegression(solver='liblinear', multi_class='ovr', random_state=0, C=param)
                LR.fit(train_embs, labels[idx_train])
                val_score = LR.score(val_embs, labels[idx_val])
                if val_score > best_val_score:
                    best_val_score = val_score
                    best_parameters = {'C': param}

            LR_best = LogisticRegression(solver='liblinear', multi_class='ovr', random_state=0, **best_parameters)

            LR_best.fit(train_embs, labels[idx_train])
            y_pred_test = LR_best.predict(test_embs)  # pred label
            print("Best accuracy on validation set:{:.4f}".format(best_val_score))
            print("Best parameters:{}".format(best_parameters))

        else:  # not use a validation set when the training labels are extremely limited
            LR = LogisticRegression(solver='liblinear', multi_class='ovr', random_state=0)
            LR.fit(train_embs, labels[idx_train])
            y_pred_test = LR.predict(test_embs)  # pred label

        test_acc = accuracy_score(labels[idx_test], y_pred_test)
        print("test accuaray:{:.4f}".format(test_acc))
        AccuaracyAll.append(test_acc)

    average_acc = np.mean(AccuaracyAll) * 100
    std_acc = np.std(AccuaracyAll) * 100
    print('avg accuracy over %d random splits: %.1f +/- %.1f, for train_num: %d, val_num:%d\n' % (
        numRandom, average_acc, std_acc, train_num, val_num))
    f.write('avg accuracy over %d random splits: %.1f +/- %.1f, for train_num: %d, val_num:%d\n' % (
        numRandom, average_acc, std_acc, train_num, val_num))
    f.flush()

    Accuaracy_test_allK.append(average_acc)

f.close()
# Out:
# Namespace(gpu=0, epochs=2000, dataset='cora', num_heads=4, num_layers=1, num_hidden=32, tau=1, seed=1, in_drop=0.6, attn_drop=0.5, lr=0.01, weight_decay=0.0001, negative_slope=0.2)
# GATConv层输入： 1433 32 4 0.6 0.5 0.2 False <function elu at 0x7f798924ecb0>
# num_layers: 1
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0001 | Time(s) 1.4539 | TrainLoss 8.2046
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0002 | Time(s) 0.7488 | TrainLoss 8.1127
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0003 | Time(s) 0.5122 | TrainLoss 8.0245
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0004 | Time(s) 0.3940 | TrainLoss 7.9509
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0005 | Time(s) 0.3231 | TrainLoss 7.8945
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0006 | Time(s) 0.2759 | TrainLoss 7.8542
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0007 | Time(s) 0.2415 | TrainLoss 7.8272
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0008 | Time(s) 0.2163 | TrainLoss 7.8085
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0009 | Time(s) 0.1967 | TrainLoss 7.7947
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0010 | Time(s) 0.1811 | TrainLoss 7.7849
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0011 | Time(s) 0.1683 | TrainLoss 7.7783
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0012 | Time(s) 0.1574 | TrainLoss 7.7740
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0013 | Time(s) 0.1484 | TrainLoss 7.7709
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0014 | Time(s) 0.1404 | TrainLoss 7.7680
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0015 | Time(s) 0.1335 | TrainLoss 7.7650
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0016 | Time(s) 0.1275 | TrainLoss 7.7623
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0017 | Time(s) 0.1223 | TrainLoss 7.7599
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0018 | Time(s) 0.1178 | TrainLoss 7.7579
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0019 | Time(s) 0.1136 | TrainLoss 7.7561
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0020 | Time(s) 0.1100 | TrainLoss 7.7543
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0021 | Time(s) 0.1067 | TrainLoss 7.7528
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0022 | Time(s) 0.1036 | TrainLoss 7.7515
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0023 | Time(s) 0.1009 | TrainLoss 7.7504
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0024 | Time(s) 0.0988 | TrainLoss 7.7495
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0025 | Time(s) 0.0963 | TrainLoss 7.7487
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0026 | Time(s) 0.0942 | TrainLoss 7.7483
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0027 | Time(s) 0.0922 | TrainLoss 7.7478
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0028 | Time(s) 0.0904 | TrainLoss 7.7474
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0029 | Time(s) 0.0886 | TrainLoss 7.7471
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0030 | Time(s) 0.0870 | TrainLoss 7.7465
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0031 | Time(s) 0.0856 | TrainLoss 7.7457
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0032 | Time(s) 0.0842 | TrainLoss 7.7449
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0033 | Time(s) 0.0828 | TrainLoss 7.7440
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0034 | Time(s) 0.0816 | TrainLoss 7.7431
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0035 | Time(s) 0.0804 | TrainLoss 7.7424
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0036 | Time(s) 0.0795 | TrainLoss 7.7417
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0037 | Time(s) 0.0785 | TrainLoss 7.7411
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0038 | Time(s) 0.0775 | TrainLoss 7.7405
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0039 | Time(s) 0.0766 | TrainLoss 7.7398
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0040 | Time(s) 0.0756 | TrainLoss 7.7393
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0041 | Time(s) 0.0748 | TrainLoss 7.7391
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0042 | Time(s) 0.0740 | TrainLoss 7.7389
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0043 | Time(s) 0.0732 | TrainLoss 7.7388
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0044 | Time(s) 0.0725 | TrainLoss 7.7384
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0045 | Time(s) 0.0718 | TrainLoss 7.7380
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0046 | Time(s) 0.0712 | TrainLoss 7.7376
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0047 | Time(s) 0.0705 | TrainLoss 7.7371
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0048 | Time(s) 0.0699 | TrainLoss 7.7367
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0049 | Time(s) 0.0693 | TrainLoss 7.7363
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0050 | Time(s) 0.0687 | TrainLoss 7.7356
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0051 | Time(s) 0.0681 | TrainLoss 7.7350
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0052 | Time(s) 0.0677 | TrainLoss 7.7345
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0053 | Time(s) 0.0671 | TrainLoss 7.7342
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0054 | Time(s) 0.0666 | TrainLoss 7.7338
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0055 | Time(s) 0.0661 | TrainLoss 7.7337
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0056 | Time(s) 0.0656 | TrainLoss 7.7337
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0057 | Time(s) 0.0651 | TrainLoss 7.7338
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0058 | Time(s) 0.0647 | TrainLoss 7.7338
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0059 | Time(s) 0.0642 | TrainLoss 7.7337
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0060 | Time(s) 0.0638 | TrainLoss 7.7334
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0061 | Time(s) 0.0634 | TrainLoss 7.7329
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0062 | Time(s) 0.0630 | TrainLoss 7.7325
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0063 | Time(s) 0.0627 | TrainLoss 7.7322
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0064 | Time(s) 0.0623 | TrainLoss 7.7319
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0065 | Time(s) 0.0620 | TrainLoss 7.7317
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0066 | Time(s) 0.0616 | TrainLoss 7.7315
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0067 | Time(s) 0.0613 | TrainLoss 7.7316
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0068 | Time(s) 0.0610 | TrainLoss 7.7317
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0069 | Time(s) 0.0606 | TrainLoss 7.7316
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0070 | Time(s) 0.0603 | TrainLoss 7.7315
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0071 | Time(s) 0.0600 | TrainLoss 7.7314
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0072 | Time(s) 0.0597 | TrainLoss 7.7313
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0073 | Time(s) 0.0594 | TrainLoss 7.7310
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0074 | Time(s) 0.0591 | TrainLoss 7.7306
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0075 | Time(s) 0.0589 | TrainLoss 7.7303
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0076 | Time(s) 0.0587 | TrainLoss 7.7302
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0077 | Time(s) 0.0584 | TrainLoss 7.7301
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0078 | Time(s) 0.0582 | TrainLoss 7.7302
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0079 | Time(s) 0.0579 | TrainLoss 7.7303
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0080 | Time(s) 0.0576 | TrainLoss 7.7305
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0081 | Time(s) 0.0574 | TrainLoss 7.7308
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0082 | Time(s) 0.0571 | TrainLoss 7.7309
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0083 | Time(s) 0.0569 | TrainLoss 7.7310
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0084 | Time(s) 0.0567 | TrainLoss 7.7310
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0085 | Time(s) 0.0564 | TrainLoss 7.7307
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0086 | Time(s) 0.0562 | TrainLoss 7.7303
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0087 | Time(s) 0.0560 | TrainLoss 7.7300
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0088 | Time(s) 0.0558 | TrainLoss 7.7295
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0089 | Time(s) 0.0556 | TrainLoss 7.7290
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0090 | Time(s) 0.0554 | TrainLoss 7.7291
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0091 | Time(s) 0.0552 | TrainLoss 7.7297
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0092 | Time(s) 0.0550 | TrainLoss 7.7303
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# ...
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0336 | Time(s) 0.0408 | TrainLoss 7.7290
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0337 | Time(s) 0.0408 | TrainLoss 7.7290
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0338 | Time(s) 0.0408 | TrainLoss 7.7290
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# Epoch 0339 | Time(s) 0.0408 | TrainLoss 7.7290
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
# early stop
# Loading 239th epoch
# NCLA当中h的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433])
# NCLA当中temp的维度： torch.Size([2708, 1433]) <class 'torch.Tensor'>
# Number of nodes: 2708
# Number of edges: 13264
# NCLA当中gat_layers后h的维度： torch.Size([2708, 4, 32])
#
# =============================1-th random split with training num 1=============================
# test accuaray:0.7416
#
# =============================2-th random split with training num 1=============================
# test accuaray:0.6179
#
# =============================3-th random split with training num 1=============================
# test accuaray:0.6583
#
# =============================4-th random split with training num 1=============================
# test accuaray:0.7394
#
# =============================5-th random split with training num 1=============================
# test accuaray:0.6146
#
# =============================6-th random split with training num 1=============================
# test accuaray:0.4554
#
# =============================7-th random split with training num 1=============================
# test accuaray:0.5927
#
# =============================8-th random split with training num 1=============================
# test accuaray:0.7375
#
# =============================9-th random split with training num 1=============================
# test accuaray:0.7242
#
# =============================10-th random split with training num 1=============================
# test accuaray:0.4384
#
# =============================11-th random split with training num 1=============================
# test accuaray:0.7334
#
# =============================12-th random split with training num 1=============================
# test accuaray:0.6838
#
# =============================13-th random split with training num 1=============================
# test accuaray:0.7371
#
# =============================14-th random split with training num 1=============================
# test accuaray:0.6572
#
# =============================15-th random split with training num 1=============================
# test accuaray:0.5020
#
# =============================16-th random split with training num 1=============================
# test accuaray:0.7331
#
# =============================17-th random split with training num 1=============================
# test accuaray:0.6546
#
# =============================18-th random split with training num 1=============================
# test accuaray:0.5006
#
# =============================19-th random split with training num 1=============================
# test accuaray:0.6475
#
# =============================20-th random split with training num 1=============================
# test accuaray:0.3887
# avg accuracy over 20 random splits: 62.8 +/- 11.0, for train_num: 1, val_num:0
#
#
# =============================1-th random split with training num 2=============================
# test accuaray:0.7832
#
# =============================2-th random split with training num 2=============================
# test accuaray:0.6971
#
# =============================3-th random split with training num 2=============================
# test accuaray:0.7628
#
# =============================4-th random split with training num 2=============================
# test accuaray:0.7368
#
# =============================5-th random split with training num 2=============================
# test accuaray:0.7658
#
# =============================6-th random split with training num 2=============================
# test accuaray:0.6689
#
# =============================7-th random split with training num 2=============================
# test accuaray:0.7186
#
# =============================8-th random split with training num 2=============================
# test accuaray:0.7335
#
# =============================9-th random split with training num 2=============================
# test accuaray:0.7687
#
# =============================10-th random split with training num 2=============================
# test accuaray:0.5724
#
# =============================11-th random split with training num 2=============================
# test accuaray:0.6867
#
# =============================12-th random split with training num 2=============================
# test accuaray:0.7569
#
# =============================13-th random split with training num 2=============================
# test accuaray:0.7446
#
# =============================14-th random split with training num 2=============================
# test accuaray:0.7353
#
# =============================15-th random split with training num 2=============================
# test accuaray:0.7506
#
# =============================16-th random split with training num 2=============================
# test accuaray:0.7383
#
# =============================17-th random split with training num 2=============================
# test accuaray:0.7164
#
# =============================18-th random split with training num 2=============================
# test accuaray:0.7056
#
# =============================19-th random split with training num 2=============================
# test accuaray:0.7390
#
# =============================20-th random split with training num 2=============================
# test accuaray:0.4521
# avg accuracy over 20 random splits: 71.2 +/- 7.5, for train_num: 2, val_num:0
#
#
# =============================1-th random split with training num 3=============================
# test accuaray:0.8039
#
# =============================2-th random split with training num 3=============================
# test accuaray:0.7213
#
# =============================3-th random split with training num 3=============================
# test accuaray:0.7879
#
# =============================4-th random split with training num 3=============================
# test accuaray:0.7562
#
# =============================5-th random split with training num 3=============================
# test accuaray:0.8095
#
# =============================6-th random split with training num 3=============================
# test accuaray:0.7834
#
# =============================7-th random split with training num 3=============================
# test accuaray:0.7838
#
# =============================8-th random split with training num 3=============================
# test accuaray:0.7592
#
# =============================9-th random split with training num 3=============================
# test accuaray:0.7644
#
# =============================10-th random split with training num 3=============================
# test accuaray:0.5984
#
# =============================11-th random split with training num 3=============================
# test accuaray:0.7317
#
# =============================12-th random split with training num 3=============================
# test accuaray:0.7633
#
# =============================13-th random split with training num 3=============================
# test accuaray:0.7417
#
# =============================14-th random split with training num 3=============================
# test accuaray:0.7864
#
# =============================15-th random split with training num 3=============================
# test accuaray:0.7912
#
# =============================16-th random split with training num 3=============================
# test accuaray:0.7417
#
# =============================17-th random split with training num 3=============================
# test accuaray:0.7313
#
# =============================18-th random split with training num 3=============================
# test accuaray:0.7328
#
# =============================19-th random split with training num 3=============================
# test accuaray:0.7614
#
# =============================20-th random split with training num 3=============================
# test accuaray:0.7179
# avg accuracy over 20 random splits: 75.3 +/- 4.4, for train_num: 3, val_num:0
#
#
# =============================1-th random split with training num 4=============================
# test accuaray:0.8101
#
# =============================2-th random split with training num 4=============================
# test accuaray:0.7194
#
# =============================3-th random split with training num 4=============================
# test accuaray:0.7817
#
# =============================4-th random split with training num 4=============================
# test accuaray:0.7675
#
# =============================5-th random split with training num 4=============================
# test accuaray:0.8198
#
# =============================6-th random split with training num 4=============================
# test accuaray:0.8019
#
# =============================7-th random split with training num 4=============================
# test accuaray:0.7728
#
# =============================8-th random split with training num 4=============================
# test accuaray:0.7593
#
# =============================9-th random split with training num 4=============================
# test accuaray:0.7754
#
# =============================10-th random split with training num 4=============================
# test accuaray:0.6593
#
# =============================11-th random split with training num 4=============================
# test accuaray:0.7586
#
# =============================12-th random split with training num 4=============================
# test accuaray:0.7791
#
# =============================13-th random split with training num 4=============================
# test accuaray:0.7750
#
# =============================14-th random split with training num 4=============================
# test accuaray:0.7903
#
# =============================15-th random split with training num 4=============================
# test accuaray:0.7959
#
# =============================16-th random split with training num 4=============================
# test accuaray:0.7429
#
# =============================17-th random split with training num 4=============================
# test accuaray:0.8019
#
# =============================18-th random split with training num 4=============================
# test accuaray:0.7701
#
# =============================19-th random split with training num 4=============================
# test accuaray:0.7869
#
# =============================20-th random split with training num 4=============================
# test accuaray:0.7567
# avg accuracy over 20 random splits: 77.1 +/- 3.4, for train_num: 4, val_num:0
#
#
# =============================1-th random split with training num 20=============================
# Best accuracy on validation set:0.7940
# Best parameters:{'C': 1}
# test accuaray:0.8340
#
# =============================2-th random split with training num 20=============================
# Best accuracy on validation set:0.8280
# Best parameters:{'C': 100}
# test accuaray:0.8050
#
# =============================3-th random split with training num 20=============================
# Best accuracy on validation set:0.7860
# Best parameters:{'C': 1}
# test accuaray:0.8250
#
# =============================4-th random split with training num 20=============================
# Best accuracy on validation set:0.8460
# Best parameters:{'C': 1}
# test accuaray:0.8390
#
# =============================5-th random split with training num 20=============================
# Best accuracy on validation set:0.8220
# Best parameters:{'C': 1}
# test accuaray:0.8330
#
# =============================6-th random split with training num 20=============================
# Best accuracy on validation set:0.8580
# Best parameters:{'C': 10}
# test accuaray:0.8410
#
# =============================7-th random split with training num 20=============================
# Best accuracy on validation set:0.8300
# Best parameters:{'C': 1}
# test accuaray:0.8310
#
# =============================8-th random split with training num 20=============================
# Best accuracy on validation set:0.8000
# Best parameters:{'C': 1}
# test accuaray:0.8040
#
# =============================9-th random split with training num 20=============================
# Best accuracy on validation set:0.8020
# Best parameters:{'C': 1}
# test accuaray:0.8250
#
# =============================10-th random split with training num 20=============================
# Best accuracy on validation set:0.8060
# Best parameters:{'C': 1}
# test accuaray:0.8120
#
# =============================11-th random split with training num 20=============================
# Best accuracy on validation set:0.8140
# Best parameters:{'C': 1}
# test accuaray:0.8330
#
# =============================12-th random split with training num 20=============================
# Best accuracy on validation set:0.8240
# Best parameters:{'C': 1}
# test accuaray:0.8040
#
# =============================13-th random split with training num 20=============================
# Best accuracy on validation set:0.8340
# Best parameters:{'C': 100}
# test accuaray:0.7910
#
# =============================14-th random split with training num 20=============================
# Best accuracy on validation set:0.8280
# Best parameters:{'C': 1}
# test accuaray:0.7990
#
# =============================15-th random split with training num 20=============================
# Best accuracy on validation set:0.8080
# Best parameters:{'C': 0.1}
# test accuaray:0.8090
#
# =============================16-th random split with training num 20=============================
# Best accuracy on validation set:0.8420
# Best parameters:{'C': 1}
# test accuaray:0.8020
#
# =============================17-th random split with training num 20=============================
# Best accuracy on validation set:0.8340
# Best parameters:{'C': 100}
# test accuaray:0.8370
#
# =============================18-th random split with training num 20=============================
# Best accuracy on validation set:0.7820
# Best parameters:{'C': 10}
# test accuaray:0.8360
#
# =============================19-th random split with training num 20=============================
# Best accuracy on validation set:0.7960
# Best parameters:{'C': 0.1}
# test accuaray:0.7970
#
# =============================20-th random split with training num 20=============================
# Best accuracy on validation set:0.8300
# Best parameters:{'C': 10}
# test accuaray:0.8320
# avg accuracy over 20 random splits: 81.9 +/- 1.6, for train_num: 20, val_num:500
